# %% [markdown]
# # Final Project: Data Science Notebook

# %% [markdown]
# ## Introduction
#
# This notebook serves as the final project submission. It demonstrates key concepts and tools in Data Science.

# %% [markdown]
# ## Data Science Languages
#
# - Python
# - R
# - SQL
# - Julia
# - Java
# - Scala

# %% [markdown]
# ## Data Science Libraries
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - PyTorch

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Description                     |
# |----------------|---------------------------------|
# | Jupyter Notebook | Interactive computing platform |
# | RStudio         | IDE for R programming          |
# | Apache Spark    | Distributed data processing    |
# | Tableau         | Data visualization tool        |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Examples of arithmetic expressions include addition, subtraction, multiplication, and division.

# %%
# Multiplication and addition
(3 * 4) + 5

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
#
# - Learn fundamental tools and libraries used in Data Science
# - Demonstrate the ability to use Jupyter Notebook effectively
# - Practice coding skills to solve data-related problems

# %% [markdown]
# ## Author
#
# Sriram Sathwik Tippavaram

# %% [markdown]
# ## Share on GitHub
#
# The notebook has been shared via GitHub for submission.

# %% [markdown]
# ## Screenshot of Notebook
#
# Include a screenshot of the first page of the notebook here.
